# %%
import pandas as pd
from glob import glob
from os import path
from tqdm.auto import tqdm

# %%
for f in tqdm(glob(f'../tiny-blue-dot/zap-n-zip/sg/csd/*.pkl')):
    if path.exists(f.replace('.pkl', '.csv')):
        continue
    if 'uncorrected' in f:
        continue
    pd.read_pickle(f).to_csv(f.replace('.pkl', '.csv'))

# %%
df = pd.read_pickle('../tiny-blue-dot/zap-n-zip/sg/csd/569062_estim_vis_2021-02-18_11-17-51_probeB_running_separated.pkl')
df
# Out:
# channel                                 0         2         4         6    \
# depth                                 -3840     -3820     -3800     -3780
# area                                    VPM       VPM       VPM       VPM
# layer
# stim_type parameter sweep time
# biphasic  35        0.0   -1.0000 -0.027842 -0.006770  0.021204  0.048733
#                           -0.9996 -0.046302 -0.042698 -0.026403  0.000407
#                           -0.9992 -0.009742  0.001292  0.012125  0.019527
#                           -0.9988  0.011301  0.026696  0.033293  0.028881
#                           -0.9984  0.007387  0.019368  0.026513  0.029611
# ...                                     ...       ...       ...       ...
# circle    white     2.0    2.9980 -0.029043 -0.062558 -0.083370 -0.093706
#                            2.9984 -0.021707 -0.064533 -0.096894 -0.114972
#                            2.9988 -0.030938 -0.070908 -0.100980 -0.118846
# ...

# %%
df = pd.read_csv('../tiny-blue-dot/zap-n-zip/sg/csd/569062_estim_vis_2021-02-18_11-17-51_probeB.csv', header=[0, 1, 2, 3], index_col=[0, 1, 2, 3])
df
# Out:
# /home/saurabh.gandhi/Projects/.env_zz/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3166: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# channel                                            0                  2  \
# depth                                          -3840              -3820
# area                                             VPM                VPM
# layer                             Unnamed: 4_level_3 Unnamed: 5_level_3
# stim_type parameter sweep time
# biphasic  35        0.0   -1.0000          -0.035049          -0.018019
#                           -0.9996          -0.060492          -0.061923
#                           -0.9992          -0.030858          -0.026766
#                           -0.9988          -0.006356           0.009203
#                           -0.9984          -0.000746           0.011608
# ...
