# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from tbd_eeg.data_analysis.eegutils import EEGexp
from tbd_eeg.data_analysis.Utilities.behavior_movies import Movie

# %% [markdown]
# ### Use Movie class

# %%
bodycam_filepath = r"/allen/programs/braintv/workgroups/nc-ophys/Leslie/eeg_pilot/mouse505550/pilot1_2020-03-02_10-08-51/recording1/200302100833-0.avi"
# body cam -0, pupil cam -1, face cam -2

# %%
sync_file = r"/allen/programs/braintv/workgroups/nc-ophys/Leslie/eeg_pilot/mouse505550/pilot1_2020-03-02_10-08-51/recording1/mouse505550_pilot1_200302_100826.sync"

# %%
sync_ch = 'behavior_camera' # sync channel name? for sync timestamps?

# %%
bodymovie = Movie(filepath=bodycam_filepath,
                 sync_filepath=sync_file,
                 sync_channel=sync_ch
                 )

# %%
bodymovie.frame_count
# Out:
# 87185

# %%
bodymovie.width
# Out:
# 1292

# %%
bodymovie.height
# Out:
# 964

# %% [markdown]
# #### Give the movie object a time (in the master clock) and it will find the correct frame.

# %%
testframe = bodymovie.get_frame(time=10.32)

# %%
fig, ax = plt.subplots(figsize=(8,6))
ax.imshow(testframe)

# %% [markdown]
# #### The code example I followed just looped through the relevant times and grabbed the nearest frame in time using the movie.get_frame(time=time_i) functions.

# %%
dir(bodymovie)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_get_array',
#  '_lazy_load',
#  'array',
#  'cap',
#  'frame_count',
#  'get_frame',
#  'height',
#  'sync_timestamps',
#  'timestamps_from_file',
#  'width']

# %%
print(bodymovie.sync_timestamps[0:5])
# Out:
# [4.02313 4.08607 4.09849 4.13172 4.16515]

# %%
print(bodymovie.timestamps_from_file[0:5])
# Out:
# [0.         0.06093577 0.09422851 0.12760759 0.16097912]
